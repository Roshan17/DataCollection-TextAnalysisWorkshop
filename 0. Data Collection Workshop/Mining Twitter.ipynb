# %% [markdown]
# #Mining the Social Web, 2nd Edition
#
# ##Chapter 1: Mining Twitter: Exploring Trending Topics, Discovering What People Are Talking About, and More
#
# This IPython Notebook provides an interactive way to follow along with and explore the numbered examples from [_Mining the Social Web (2nd Edition)_](http://bit.ly/135dHfs). The intent behind this notebook is to reinforce the concepts from the sample code in a fun, convenient, and effective way. This notebook assumes that you are reading along with the book and have the context of the discussion as you work through these exercises.
#
# In the somewhat unlikely event that you've somehow stumbled across this notebook outside of its context on GitHub, [you can find the full source code repository here](http://bit.ly/16kGNyb).
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application. There are four primary identifiers you'll need to note for an OAuth 1.0A workflow: consumer key, consumer secret, access token, and access token secret. Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.
#
# <img src="files/resources/ch01-twitter/images/Twitter-AppCredentials.png" width="600px">

# %% [markdown]
# If you are taking advantage of the virtual machine experience for this chapter that is powered by Vagrant, you should just be able to execute the code in this notebook without any worries whatsoever about installing dependencies. If you are running the code from your own development envioronment, however, be advised that these examples in this chapter take advantage of a Python package called [twitter](https://github.com/sixohsix/twitter) to make API calls. You can install this package in a terminal with [pip](https://pypi.python.org/pypi/pip) with the command `pip install twitter`, preferably from within a [Python virtual environment](https://pypi.python.org/pypi/virtualenv).

# %% [markdown]
# Once installed, you should be able to open up a Python interpreter (or better yet, your [IPython](http://ipython.org/) interpreter) and get rolling.

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter
from twitter import *
from twitter import oauth

# XXX: Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = '2RPNIGYfRLCfqN7T45OPwVahl'
CONSUMER_SECRET ='ruqEI6H3WLgoJ2n2zklqp6KfrfdVgLZorQWrD3r91AibQRtO8M'
OAUTH_TOKEN = '992687512727441408-zqC4bIM591sMuBJ3PT7DaaWHKoQnrmt'
OAUTH_TOKEN_SECRET = 'z1RDHvJTWokKdqfDKeDiNEktWlo3lqosbqtE49GyKXgpe'


# keys and tokens from the Twitter Dev Console
#consumer_key = '2RPNIGYfRLCfqN7T45OPwVahl'
#consumer_secret = 'ruqEI6H3WLgoJ2n2zklqp6KfrfdVgLZorQWrD3r91AibQRtO8M'
#access_token = '992687512727441408-zqC4bIM591sMuBJ3PT7DaaWHKoQnrmt'
#access_token_secret = 'z1RDHvJTWokKdqfDKeDiNEktWlo3lqosbqtE49GyKXgpe'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x7f179810e4e0>

# %% [markdown]
# ## Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
print()
print(us_trends)
# Out:
# [{'trends': [{'name': '성격의 어두운', 'url': 'http://twitter.com/search?q=%22%EC%84%B1%EA%B2%A9%EC%9D%98+%EC%96%B4%EB%91%90%EC%9A%B4%22', 'promoted_content': None, 'query': '%22%EC%84%B1%EA%B2%A9%EC%9D%98+%EC%96%B4%EB%91%90%EC%9A%B4%22', 'tweet_volume': None}, {'name': '#CarterV', 'url': 'http://twitter.com/search?q=%23CarterV', 'promoted_content': None, 'query': '%23CarterV', 'tweet_volume': 92071}, {'name': '#Sabarimala', 'url': 'http://twitter.com/search?q=%23Sabarimala', 'promoted_content': None, 'query': '%23Sabarimala', 'tweet_volume': 21407}, {'name': '#RyderCup', 'url': 'http://twitter.com/search?q=%23RyderCup', 'promoted_content': None, 'query': '%23RyderCup', 'tweet_volume': 47348}, {'name': '#FridayFeeling', 'url': 'http://twitter.com/search?q=%23FridayFeeling', 'promoted_content': None, 'query': '%23FridayFeeling', 'tweet_volume': 24481}, {'name': '#TheVoiceBrasil', 'url': 'http://twitter.com/search?q=%23TheVoiceBrasil', 'promoted_content': None, 'query': '%23TheVoiceBrasil', 'tweet_volume': 75773}, {'name': 'Hayırlı Cumalar', 'url': 'http://twitter.com/search?q=%22Hay%C4%B1rl%C4%B1+Cumalar%22', 'promoted_content': None, 'query': '%22Hay%C4%B1rl%C4%B1+Cumalar%22', 'tweet_volume': 36250}, {'name': 'Rams', 'url': 'http://twitter.com/search?q=Rams', 'promoted_content': None, 'query': 'Rams', 'tweet_volume': 104583}, {'name': 'Guillermo', 'url': 'http://twitter.com/search?q=Guillermo', 'promoted_content': None, 'query': 'Guillermo', 'tweet_volume': 62729}, {'name': '無料10連', 'url': 'http://twitter.com/search?q=%E7%84%A1%E6%96%9910%E9%80%A3', 'promoted_content': None, 'query': '%E7%84%A1%E6%96%9910%E9%80%A3', 'tweet_volume': None}, {'name': 'Kevin', 'url': 'http://twitter.com/search?q=Kevin', 'promoted_content': None, 'query': 'Kevin', 'tweet_volume': 151258}, {'name': 'American Bar Association', 'url': 'http://twitter.com/search?q=%22American+Bar+Association%22', 'promoted_content': None, 'query': '%22American+Bar+Association%22', 'tweet_volume': 122871}, {'name': 'Luca Brasi 3', 'url': 'http://twitter.com/search?q=%22Luca+Brasi+3%22', 'promoted_content': None, 'query': '%22Luca+Brasi+3%22', 'tweet_volume': 17018}, {'name': 'Used 2', 'url': 'http://twitter.com/search?q=%22Used+2%22', 'promoted_content': None, 'query': '%22Used+2%22', 'tweet_volume': None}, {'name': '이오리', 'url': 'http://twitter.com/search?q=%EC%9D%B4%EC%98%A4%EB%A6%AC', 'promoted_content': None, 'query': '%EC%9D%B4%EC%98%A4%EB%A6%AC', 'tweet_volume': None}, {'name': '심재철', 'url': 'http://twitter.com/search?q=%EC%8B%AC%EC%9E%AC%EC%B2%A0', 'promoted_content': None, 'query': '%EC%8B%AC%EC%9E%AC%EC%B2%A0', 'tweet_volume': 60369}, {'name': 'Dark Side of the Moon', 'url': 'http://twitter.com/search?q=%22Dark+Side+of+the+Moon%22', 'promoted_content': None, 'query': '%22Dark+Side+of+the+Moon%22', 'tweet_volume': 11801}, {'name': '自信診断', 'url': 'http://twitter.com/search?q=%E8%87%AA%E4%BF%A1%E8%A8%BA%E6%96%AD', 'promoted_content': None, 'query': '%E8%87%AA%E4%BF%A1%E8%A8%BA%E6%96%AD', 'tweet_volume': 12181}, {'name': '유즈루', 'url': 'http://twitter.com/search?q=%EC%9C%A0%EC%A6%88%EB%A3%A8', 'promoted_content': None, 'query': '%EC%9C%A0%EC%A6%88%EB%A3%A8', 'tweet_volume': None}, {'name': "Don't Cry", 'url': 'http://twitter.com/search?q=%22Don%27t+Cry%22', 'promoted_content': None, 'query': '%22Don%27t+Cry%22', 'tweet_volume': 19787}, {'name': 'Let It Fly', 'url': 'http://twitter.com/search?q=%22Let+It+Fly%22', 'promoted_content': None, 'query': '%22Let+It+Fly%22', 'tweet_volume': None}, {'name': '#FelizFinde', 'url': 'http://twitter.com/search?q=%23FelizFinde', 'promoted_content': None, 'query': '%23FelizFinde', 'tweet_volume': None}, {'name': '#لعبه_ادمنتها', 'url': 'http://twitter.com/search?q=%23%D9%84%D8%B9%D8%A8%D9%87_%D8%A7%D8%AF%D9%85%D9%86%D8%AA%D9%87%D8%A7', 'promoted_content': None, 'query': '%23%D9%84%D8%B9%D8%A8%D9%87_%D8%A7%D8%AF%D9%85%D9%86%D8%AA%D9%87%D8%A7', 'tweet_volume': 14241}, {'name': '#الجمعه', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D ...
#
# [{'trends': [{'name': 'Wayne', 'url': 'http://twitter.com/search?q=Wayne', 'promoted_content': None, 'query': 'Wayne', 'tweet_volume': 551648}, {'name': '#RyderCup', 'url': 'http://twitter.com/search?q=%23RyderCup', 'promoted_content': None, 'query': '%23RyderCup', 'tweet_volume': 47734}, {'name': '#YSIV', 'url': 'http://twitter.com/search?q=%23YSIV', 'promoted_content': None, 'query': '%23YSIV', 'tweet_volume': 24498}, {'name': 'American Bar Association', 'url': 'http://twitter.com/search?q=%22American+Bar+Association%22', 'promoted_content': None, 'query': '%22American+Bar+Association%22', 'tweet_volume': 123700}, {'name': 'Jared Goff', 'url': 'http://twitter.com/search?q=%22Jared+Goff%22', 'promoted_content': None, 'query': '%22Jared+Goff%22', 'tweet_volume': 35348}, {'name': '#HTGAWM', 'url': 'http://twitter.com/search?q=%23HTGAWM', 'promoted_content': None, 'query': '%23HTGAWM', 'tweet_volume': 55983}, {'name': 'Logic', 'url': 'http://twitter.com/search?q=Logic', 'promoted_content': None, 'query': 'Logic', 'tweet_volume': 196889}, {'name': 'Gates', 'url': 'http://twitter.com/search?q=Gates', 'promoted_content': None, 'query': 'Gates', 'tweet_volume': 44514}, {'name': 'Kodak', 'url': 'http://twitter.com/search?q=Kodak', 'promoted_content': None, 'query': 'Kodak', 'tweet_volume': 37327}, {'name': '#MurphyBrown', 'url': 'http://twitter.com/search?q=%23MurphyBrown', 'promoted_content': None, 'query': '%23MurphyBrown', 'tweet_volume': 14468}, {'name': '#SOLITASZN', 'url': 'http://twitter.com/search?q=%23SOLITASZN', 'promoted_content': None, 'query': '%23SOLITASZN', 'tweet_volume': None}, {'name': 'Special Delivery', 'url': 'http://twitter.com/search?q=%22Special+Delivery%22', 'promoted_content': None, 'query': '%22Special+Delivery%22', 'tweet_volume': None}, {'name': 'Dope New Gospel', 'url': 'http://twitter.com/search?q=%22Dope+New+Gospel%22', 'promoted_content': None, 'query': '%22Dope+New+Gospel%22', 'tweet_volume': None}, {'name': 'The Rams', 'url': 'http://twitter.com/search?q=%22The+Rams%22', 'promoted_content': None, 'query': '%22The+Rams%22', 'tweet_volume': 33407}, {'name': 'Dedicate', 'url': 'http://twitter.com/search?q=Dedicate', 'promoted_content': None, 'query': 'Dedicate', 'tweet_volume': 18783}, {'name': 'Golf Channel', 'url': 'http://twitter.com/search?q=%22Golf+Channel%22', 'promoted_content': None, 'query': '%22Golf+Channel%22', 'tweet_volume': None}, {'name': 'Sampha', 'url': 'http://twitter.com/search?q=Sampha', 'promoted_content': None, 'query': 'Sampha', 'tweet_volume': None}, {'name': 'Mannie Fresh', 'url': 'http://twitter.com/search?q=%22Mannie+Fresh%22', 'promoted_content': None, 'query': '%22Mannie+Fresh%22', 'tweet_volume': None}, {'name': 'Lyin', 'url': 'http://twitter.com/search?q=Lyin', 'promoted_content': None, 'query': 'Lyin', 'tweet_volume': None}, {'name': '#TakiTaki', 'url': 'http://twitter.com/search?q=%23TakiTaki', 'promoted_content': None, 'query': '%23TakiTaki', 'tweet_volume': 78895}, {'name': '#SaveTheOnlyReason', 'url': 'http://twitter.com/search?q=%23SaveTheOnlyReason', 'promoted_content': None, 'query': '%23SaveTheOnlyReason', 'tweet_volume': None}, {'name': '#RejectedBowlingLeagueNames', 'url': 'http://twitter.com/search?q=%23RejectedBowlingLeagueNames', 'promoted_content': None, 'query': '%23RejectedBowlingLeagueNames', 'tweet_volume': None}, {'name': '#Sabarimala', 'url': 'http://twitter.com/search?q=%23Sabarimala', 'promoted_content': None, 'query': '%23Sabarimala', 'tweet_volume': 21875}, {'name': '#DarkSideOfTheMoon', 'url': 'http://twitter.com/search?q=%23DarkSideOfTheMoon', 'promoted_content': None, 'query': '%23DarkSideOfTheMoon', 'tweet_volume': None}, {'name': '#KavanaughHearings', 'url': 'http://twitter.com/search?q=%23KavanaughHearings', 'promoted_content': None, 'query': '%23KavanaughHearings', 'tweet_volume': 1947005}], 'as_of': '2018-09-28T08:09:48Z', 'created_at': '2018-09-28T08:08:01Z', 'locations': [{'name': 'United States', 'woeid': 23424977}]}]

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print(json.dumps(world_trends, indent=1))
print()
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "\uc131\uaca9\uc758 \uc5b4\ub450\uc6b4",
#     "url": "http://twitter.com/search?q=%22%EC%84%B1%EA%B2%A9%EC%9D%98+%EC%96%B4%EB%91%90%EC%9A%B4%22",
#     "promoted_content": null,
#     "query": "%22%EC%84%B1%EA%B2%A9%EC%9D%98+%EC%96%B4%EB%91%90%EC%9A%B4%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CarterV",
#     "url": "http://twitter.com/search?q=%23CarterV",
#     "promoted_content": null,
#     "query": "%23CarterV",
#     "tweet_volume": 92071
#    },
#    {
#     "name": "#Sabarimala",
#     "url": "http://twitter.com/search?q=%23Sabarimala",
#     "promoted_content": null,
#     "query": "%23Sabarimala",
#     "tweet_volume": 21407
#    },
#    {
#     "name": "#RyderCup",
#     "url": "http://twitter.com/search?q=%23RyderCup",
#     "promoted_content": null,
#     "query": "%23RyderCup",
#     "tweet_volume": 47348
#    },
#    {
#     "name": "#FridayFeeling",
#     "url": "http://twitter.com/search?q=%23FridayFeeling",
#     "promoted_content": null,
#     "query": "%23FridayFeeling",
#     "tweet_volume": 24481
#    },
#    {
#     "name": "#TheVoiceBrasil",
#     "url": "http://twitter.com/search?q=%23TheVoiceBrasil",
#     "promoted_content": null,
#     "query": "%23TheVoiceBrasil",
#     "tweet_volume": 75773
#    },
#    {
#     "name": "Hay\u0131rl\u0131 Cumalar",
#     "url": "http://twitter.com/search?q=%22Hay%C4%B1rl%C4%B1+Cumalar%22",
#     "promoted_content": null,
#     "query": "%22Hay%C4%B1rl%C4%B1+Cumalar%22",
#     "tweet_volume": 36250
#    },
#    {
#     "name": "Rams",
#     "url": "http://twitter.com/search?q=Rams",
#     "promoted_content": null,
#     "query": "Rams",
#     "tweet_volume": 104583
#    },
#    {
#     "name": "Guillermo",
#     "url": "http://twitter.com/search?q=Guillermo",
#     "promoted_content": null,
#     "query": "Guillermo",
#     "tweet_volume": 62729
#    },
#    {
#     "name": "\u7121\u659910\u9023",
#     "url": "http://twitter.com/search?q=%E7%84%A1%E6%96%9910%E9%80%A3",
#     "promoted_content": null,
#     "query": "%E7%84%A1%E6%96%9910%E9%80%A3",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kevin",
#     "url": "http://twitter.com/search?q=Kevin",
#     "promoted_content": null,
#     "query": "Kevin",
#     "tweet_volume": 151258
#    },
#    {
#     "name": "American Bar Association",
#     "url": "http://twitter.com/search?q=%22American+Bar+Association%22",
#     "promoted_content": null,
#     "query": "%22American+Bar+Association%22",
#     "tweet_volume": 122871
#    },
#    {
#     "name": "Luca Brasi 3",
#     "url": "http://twitter.com/search?q=%22Luca+Brasi+3%22",
#     "promoted_content": null,
#     "query": "%22Luca+Brasi+3%22",
#     "tweet_volume": 17018
#    },
#    {
#     "name": "Used 2",
#     "url": "http://twitter.com/search?q=%22Used+2%22",
#     "promoted_content": null,
#     "query": "%22Used+2%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\uc774\uc624\ub9ac",
#     "url": "http://twitter.com/search?q=%EC%9D%B4%EC%98%A4%EB%A6%AC",
#     "promoted_content": null,
#     "query": "%EC%9D%B4%EC%98%A4%EB%A6%AC",
#     "tweet_volume": null
#    },
#    {
#     "name": "\uc2ec\uc7ac\ucca0",
#     "url": "http://twitter.com/search?q=%EC%8B%AC%EC%9E%AC%EC%B2%A0",
#     "promoted_content": null,
#     "query": "%EC%8B%AC%EC%9E%AC%EC%B2%A0",
#     "tweet_volume": 60369
#    },
#    {
#     "name": "Dark Side of the Moon",
#     "url": "http://twitter.com/search?q=%22Dark+Side+of+the+Moon%22",
#     "promoted_content": null,
#     "query": "%22Dark+Side+of+the+Moon%22",
#     "tweet_volume": 11801
#    },
#    {
#     "name": "\u81ea\u4fe1\u8a3a\u65ad",
#     "url": "http://twitter.com/search?q=%E8%87%AA%E4%BF%A1%E8%A8%BA%E6%96%AD",
#     "promoted_content": null,
#     "query": "%E8%87%AA%E4%BF%A1%E8%A8%BA%E6%96%AD",
#     "tweet_volume": 12181
#    },
#    {
#     "name": "\uc720\uc988\ub8e8",
#     "url": "http://twitter.com/search?q=%EC%9C%A0%EC%A6%88%EB%A3%A8",
#     "promoted_content": null,
#     "query": "%EC%9C%A0%EC%A6%88%EB%A3%A8",
#     "tweet_volume": null
#    },
#    {
#     "name": "Don't Cry",
#     "url": "http://twitter.com/search?q=%22Don%27t+Cry%22",
#     "promoted_content": null,
#     "query": "%22Don%27t+Cry%22",
#     "tweet_volume": 19787
#    },
#    {
#     "name": "Let It Fly",
#     "url": "http://twitter.com/search?q=%22Let+It+Fly%22",
#     "promoted_content": null,
#     "query": "%22Let+It+Fly%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FelizFinde",
#     "url": "http://twitter.com/search?q=%23FelizFinde",
#     "promoted_content": null,
#     "query": "%23FelizFinde",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0644\u0639\u0628\u0647_\u0627\u062f\u0645\u0646\u062a\u0647\u0627",
#     "url": "http://twitter.com/search?q=%23%D9%84%D8%B9%D8%A8%D9%87_%D8%A7%D8%AF%D9%85%D9%86%D8%AA%D9%87%D8%A7",
#     "promoted_content": null,
#     "query": "%23%D9%84%D8%B9%D8%A8%D9%87_%D8%A7%D8%AF%D9%85%D9%86%D8%AA%D9%87%D8%A7",
#     "tweet_volume": 14241
#    },
#    {
#     "name": "#\u0627\u0644\u062c\u0645\u0639\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%AC%D9%85%D8%B9%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%AC%D9%85%D8%B9%D9%87",
#     "tweet_volume": 55245
#    },
#    {
#     "name": "#BhimaKoregaon",
#     "url": "http://twitter.com/search?q=%23BhimaKoregaon",
#     "promoted_content": null,
#     "query": "%23BhimaKoregaon",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ManovraDelPopolo",
#     "url": "http://twitter.com/search?q=%23ManovraDelPopolo",
#     "promoted_content": null,
#     "query": "%23ManovraDelPopolo",
#     "tweet_volume": 22870
#    },
#    {
#     "name": "#Elimina\u00e7\u00e3oAFazenda",
#     "url": "http://twitter.com/search?q=%23Elimina%C3%A7%C3%A3oAFazenda",
#     "promoted_content": null,
#     "query": "%23Elimina%C3%A7%C3%A3oAFazenda",
#     "tweet_volume": 55712
#    },
#    {
#     "name": "#ShaheedBhagatSingh",
#     "url": "http://twitter.com/search?q=%23ShaheedBhagatSingh",
#     "promoted_content": null,
#     "query": "%23ShaheedBhagatSingh",
#     "tweet_volume": 31292
#    },
#    {
#     "name": "#VendrediLecture",
#     "url": "http://twitter.com/search?q=%23VendrediLecture",
#     "promoted_content": null,
#     "query": "%23VendrediLecture",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u062c\u0645\u0639\u0647_\u0645\u0628\u0627\u0631\u0643\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%AC%D9%85%D8%B9%D9%87_%D9%85%D8%A8%D8%A7%D8%B1%D9%83%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%AC%D9%85%D8%B9%D9%87_%D9%85%D8%A8%D8%A7%D8%B1%D9%83%D9%87",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HTGAWM",
#     "url": "http://twitter.com/search?q=%23HTGAWM",
#     "promoted_content": null,
#     "query": "%23HTGAWM",
#     "tweet_volume": 55939
#    },
#    {
#     "name": "#TakiTaki",
#     "url": "http://twitter.com/search?q=%23TakiTaki",
#     "promoted_content": null,
#     "query": "%23TakiTaki",
#     "tweet_volume": 78622
#    },
#    {
#     "name": "#28settembre",
#     "url": "http://twitter.com/search?q=%2328settembre",
#     "promoted_content": null,
#     "query": "%2328settembre",
#     "tweet_volume": null
#    },
#    {
#     "name": "#YSIV",
#     "url": "http://twitter.com/search?q=%23YSIV",
#     "promoted_content": null,
#     "query": "%23YSIV",
#     "tweet_volume": 24427
#    },
#    {
#     "name": "#ProtestoEdiyorum",
#     "url": "http://twitter.com/search?q=%23ProtestoEdiyorum",
#     "promoted_content": null,
#     "query": "%23ProtestoEdiyorum",
#     "tweet_volume": null
#    },
#    {
#     "name": "#URITeaser",
#     "url": "http://twitter.com/search?q=%23URITeaser",
#     "promoted_content": null,
#     "query": "%23URITeaser",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BBCMusicDay",
#     "url": "http://twitter.com/search?q=%23BBCMusicDay",
#     "promoted_content": null,
#     "query": "%23BBCMusicDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#VEJA600MILHOES",
#     "url": "http://twitter.com/search?q=%23VEJA600MILHOES",
#     "promoted_content": null,
#     "query": "%23VEJA600MILHOES",
#     "tweet_volume": 34361
#    },
#    {
#     "name": "#\u0627\u062c\u0645\u0644_\u0643\u0644\u0627\u0645_\u0641\u064a_\u062a\u0648\u064a\u062a\u0631",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%AC%D9%85%D9%84_%D9%83%D9%84%D8%A7%D9%85_%D9%81%D9%8A_%D8%AA%D9%88%D9%8A%D8%AA%D8%B1",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D8%AC%D9%85%D9%84_%D9%83%D9%84%D8%A7%D9%85_%D9%81%D9%8A_%D8%AA%D9%88%D9%8A%D8%AA%D8%B1",
#     "tweet_volume": 10184
#    },
#    {
#     "name": "#HappyBirthdayRanbirKapoor",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayRanbirKapoor",
#     "promoted_content": null,
#     "query": "%23HappyBirthdayRanbirKapoor",
#     "tweet_volume": 14749
#    },
#    {
#     "name": "#\u0627\u0644\u0627_\u0631\u064a\u0645_\u0644\u0627\u062a\u0632\u0639\u0644\u0648\u0646\u0647\u0627",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A7_%D8%B1%D9%8A%D9%85_%D9%84%D8%A7%D8%AA%D8%B2%D8%B9%D9%84%D9%88%D9%86%D9%87%D8%A7",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%A7_%D8%B1%D9%8A%D9%85_%D9%84%D8%A7%D8%AA%D8%B2%D8%B9%D9%84%D9%88%D9%86%D9%87%D8%A7",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BankingRC",
#     "url": "http://twitter.com/search?q=%23BankingRC",
#     "promoted_content": null,
#     "query": "%23BankingRC",
#     "tweet_volume": null
#    },
#    {
#     "name": "#STOP\u6d77\u8cca\u7248",
#     "url": "http://twitter.com/search?q=%23STOP%E6%B5%B7%E8%B3%8A%E7%89%88",
#     "promoted_content": null,
#     "query": "%23STOP%E6%B5%B7%E8%B3%8A%E7%89%88",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SuiDhaaga",
#     "url": "http://twitter.com/search?q=%23SuiDhaaga",
#     "promoted_content": null,
#     "query": "%23SuiDhaaga",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OTDirecto28SEP",
#     "url": "http://twitter.com/search?q=%23OTDirecto28SEP",
#     "promoted_content": null,
#     "query": "%23OTDirecto28SEP",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MiPrimeraDieta",
#     "url": "http://twitter.com/search?q=%23MiPrimeraDieta",
#     "promoted_content": null,
#     "query": "%23MiPrimeraDieta",
#     "tweet_volume": null
#    },
#    {
#     "name": "#127A\u00f1osDeGloria",
#     "url": "http://twitter.com/search?q=%23127A%C3%B1osDeGloria",
#     "promoted_content": null,
#     "query": "%23127A%C3%B1osDeGloria",
#     "tweet_volume": 31158
#    },
#    {
#     "name": "#LataMangeshkar",
#     "url": "http://twitter.com/search?q=%23LataMangeshkar",
#     "promoted_content": null,
#     "query": "%23LataMangeshkar",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Turgut\u00d6zakman",
#     "url": "http://twitter.com/search?q=%23Turgut%C3%96zakman",
#     "promoted_content": null,
#     "query": "%23Turgut%C3%96zakman",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MurphyBrown",
#     "url": "http://twitter.com/search?q=%23MurphyBrown",
#     "promoted_content": null,
#     "query": "%23MurphyBrown",
#     "tweet_volume": 14429
#    }
#   ],
#   "as_of": "2018-09-28T08:09:47Z",
#   "created_at": "2018-09-28T08:03:00Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "trends": [
#    {
#     "name": "Wayne",
#     "url": "http://twitter.com/search?q=Wayne",
#     "promoted_content": null,
#     "query": "Wayne",
#     "tweet_volume": 551648
#    },
#    {
#     "name": "#RyderCup",
#     "url": "http://twitter.com/search?q=%23RyderCup",
#     "promoted_content": null,
#     "query": "%23RyderCup",
#     "tweet_volume": 47734
#    },
#    {
#     "name": "#YSIV",
#     "url": "http://twitter.com/search?q=%23YSIV",
#     "promoted_content": null,
#     "query": "%23YSIV",
#     "tweet_volume": 24498
#    },
#    {
#     "name": "American Bar Association",
#     "url": "http://twitter.com/search?q=%22American+Bar+Association%22",
#     "promoted_content": null,
#     "query": "%22American+Bar+Association%22",
#     "tweet_volume": 123700
#    },
#    {
#     "name": "Jared Goff",
#     "url": "http://twitter.com/search?q=%22Jared+Goff%22",
#     "promoted_content": null,
#     "query": "%22Jared+Goff%22",
#     "tweet_volume": 35348
#    },
#    {
#     "name": "#HTGAWM",
#     "url": "http://twitter.com/search?q=%23HTGAWM",
#     "promoted_content": null,
#     "query": "%23HTGAWM",
#     "tweet_volume": 55983
#    },
#    {
#     "name": "Logic",
#     "url": "http://twitter.com/search?q=Logic",
#     "promoted_content": null,
#     "query": "Logic",
#     "tweet_volume": 196889
#    },
#    {
#     "name": "Gates",
#     "url": "http://twitter.com/search?q=Gates",
#     "promoted_content": null,
#     "query": "Gates",
#     "tweet_volume": 44514
#    },
#    {
#     "name": "Kodak",
#     "url": "http://twitter.com/search?q=Kodak",
#     "promoted_content": null,
#     "query": "Kodak",
#     "tweet_volume": 37327
#    },
#    {
#     "name": "#MurphyBrown",
#     "url": "http://twitter.com/search?q=%23MurphyBrown",
#     "promoted_content": null,
#     "query": "%23MurphyBrown",
#     "tweet_volume": 14468
#    },
#    {
#     "name": "#SOLITASZN",
#     "url": "http://twitter.com/search?q=%23SOLITASZN",
#     "promoted_content": null,
#     "query": "%23SOLITASZN",
#     "tweet_volume": null
#    },
#    {
#     "name": "Special Delivery",
#     "url": "http://twitter.com/search?q=%22Special+Delivery%22",
#     "promoted_content": null,
#     "query": "%22Special+Delivery%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Dope New Gospel",
#     "url": "http://twitter.com/search?q=%22Dope+New+Gospel%22",
#     "promoted_content": null,
#     "query": "%22Dope+New+Gospel%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Rams",
#     "url": "http://twitter.com/search?q=%22The+Rams%22",
#     "promoted_content": null,
#     "query": "%22The+Rams%22",
#     "tweet_volume": 33407
#    },
#    {
#     "name": "Dedicate",
#     "url": "http://twitter.com/search?q=Dedicate",
#     "promoted_content": null,
#     "query": "Dedicate",
#     "tweet_volume": 18783
#    },
#    {
#     "name": "Golf Channel",
#     "url": "http://twitter.com/search?q=%22Golf+Channel%22",
#     "promoted_content": null,
#     "query": "%22Golf+Channel%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sampha",
#     "url": "http://twitter.com/search?q=Sampha",
#     "promoted_content": null,
#     "query": "Sampha",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mannie Fresh",
#     "url": "http://twitter.com/search?q=%22Mannie+Fresh%22",
#     "promoted_content": null,
#     "query": "%22Mannie+Fresh%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lyin",
#     "url": "http://twitter.com/search?q=Lyin",
#     "promoted_content": null,
#     "query": "Lyin",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TakiTaki",
#     "url": "http://twitter.com/search?q=%23TakiTaki",
#     "promoted_content": null,
#     "query": "%23TakiTaki",
#     "tweet_volume": 78895
#    },
#    {
#     "name": "#SaveTheOnlyReason",
#     "url": "http://twitter.com/search?q=%23SaveTheOnlyReason",
#     "promoted_content": null,
#     "query": "%23SaveTheOnlyReason",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RejectedBowlingLeagueNames",
#     "url": "http://twitter.com/search?q=%23RejectedBowlingLeagueNames",
#     "promoted_content": null,
#     "query": "%23RejectedBowlingLeagueNames",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Sabarimala",
#     "url": "http://twitter.com/search?q=%23Sabarimala",
#     "promoted_content": null,
#     "query": "%23Sabarimala",
#     "tweet_volume": 21875
#    },
#    {
#     "name": "#DarkSideOfTheMoon",
#     "url": "http://twitter.com/search?q=%23DarkSideOfTheMoon",
#     "promoted_content": null,
#     "query": "%23DarkSideOfTheMoon",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KavanaughHearings",
#     "url": "http://twitter.com/search?q=%23KavanaughHearings",
#     "promoted_content": null,
#     "query": "%23KavanaughHearings",
#     "tweet_volume": 1947005
#    }
#   ],
#   "as_of": "2018-09-28T08:09:48Z",
#   "created_at": "2018-09-28T08:08:01Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'#HTGAWM', '#MurphyBrown', '#RyderCup', '#Sabarimala', '#YSIV', 'American Bar Association', '#TakiTaki'}

# %% [markdown]
# ## Example 5. Collecting search results

# %%
# Import unquote to prevent url encoding errors in next_results
#from urllib import unquote
from urllib.parse import unquote

# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = 'lionel messi' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError as e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
#print(statuses)
print(json.dumps(statuses[0], indent=1))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 300
# Length of statuses 400
# Length of statuses 496
# {
#  "created_at": "Fri Sep 28 08:20:33 +0000 2018",
#  "id": 1045589064081190912,
#  "id_str": "1045589064081190912",
#  "text": "\ud83e\udde4\u26bd Penalty Expert!\n\nDid you know, Brazilian international @diegoalvesgol has saved more than half the penalties he\u2026 https://t.co/nIM5wgqgQf",
#  "truncated": true,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "diegoalvesgol",
#     "name": "Diego Alves",
#     "id": 990730634090958855,
#     "id_str": "990730634090958855",
#     "indices": [
#      58,
#      72
#     ]
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/nIM5wgqgQf",
#     "expanded_url": "https://twitter.com/i/web/status/1045589064081190912",
#     "display_url": "twitter.com/i/web/status/1\u2026",
#     "indices": [
#      116,
#      139
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 3200851570,
#   "id_str": "3200851570",
#   "name": "Sportpesa News",
#   "screen_name": "SportpesaNews",
#   "location": "Nairobi, Kenya",
#   "description": "Leading Sports News Provider. Follow us for the latest in your favorite sports.",
#   "url": "https://t.co/9njTVkfKZm",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/9njTVkfKZm",
#       "expanded_url": "http://www.sportpesanews.com",
#       "display_url": "sportpesanews.com",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 18521,
#   "friends_count": 71,
#   "listed_count": 18,
#   "created_at": "Fri Apr 24 11:17:17 +0000 2015",
#   "favourites_count": 951,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 16950,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/976085967265304576/kzbhTBue_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/976085967265304576/kzbhTBue_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/3200851570/1528875623",
#   "profile_link_color": "0084B4",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": false,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %% [markdown]
# Note: Should you desire to do so, you can load the same set of search results that are illustrated in the text of _Mining the Social Web_ by executing the code below that reads a snapshot of the data and stores it into the same statuses variable as was defined above. Alternatively, you can choose to skip execution of this cell in order to follow along with your own data.

# %%
import json
statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())

# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = [ status 
      for status in statuses
          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted_status'])

# Can you find the most retweeted tweet in your search results? Try do do it!
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-be6b9262b2fe> in <module>()
#       1 import json
# ----> 2 statuses = json.loads(open('resources/ch01-twitter/data/MentionSomeoneImportantForYou.json').read())
#       3
#       4 # The result of the list comprehension is a list with only one element that
#       5 # can be accessed by its index and set to the variable t
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/ch01-twitter/data/MentionSomeoneImportantForYou.json'

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "\ud83e\udde4\u26bd Penalty Expert!\n\nDid you know, Brazilian international @diegoalvesgol has saved more than half the penalties he\u2026 https://t.co/nIM5wgqgQf",
#  "RT @termo_neitor: Thiago Messi a Lionel Messi https://t.co/m7hptboz32",
#  "RT @MessiLeoBrasil: Jogadores com mais gols em um \u00fanico ano:\n\n\ud83c\udde6\ud83c\uddf7 1\u00b0 Lionel Messi - 91 gols\n\ud83c\udde9\ud83c\uddea 2\u00b0 Gerd M\u00fcller - 85 gols\n\ud83c\udde7\ud83c\uddf7 3\u00b0 Pel\u00e9 - 75 gols\u2026",
#  "In the 2015 Rivers guber, we played a match with a highly equipped team(the PDP) but we benched our Lionel Messi,\u2026 https://t.co/5d08srdNaK",
#  "RT @ryangoldy8: It\u2019s ok lads next week it won\u2019t be Isaac Success and Etienne Capoue, Just Lionel Messi and Luis Suarez"
# ]
# [
#  "diegoalvesgol",
#  "termo_neitor",
#  "MessiLeoBrasil",
#  "ryangoldy8",
#  "YouTube"
# ]
# [
#  "epl",
#  "Messi",
#  "Goalphabet",
#  "LionelMessi",
#  "CFC"
# ]
# [
#  "\ud83e\udde4\u26bd",
#  "Penalty",
#  "Expert!",
#  "Did",
#  "you"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('Lionel', 417), ('RT', 323), ('Messi', 287), ('-', 206), ('gols', 156), ('a', 142), ('em', 103), ('to', 98), ('in', 91), ('🇦🇷', 89)]
#
# [('MessiLeoBrasil', 52), ('BarcaTimes', 45), ('CuriosidadesEU', 25), ('YouTube', 23), ('InvictosSomos', 17), ('BarclaysLeague', 11), ('ChelseaFC', 11), ('Bundesliga_EN', 11), ('Squawka', 10), ('BTLComps', 10)]
#
# [('Messi', 13), ('Goalphabet', 11), ('futbol', 9), ('deporte', 9), ('cfc', 3), ('SelfImprovement', 2), ('Motivation', 2), ('epl', 1), ('LionelMessi', 1), ('CFC', 1)]

# %% [markdown]
# ## Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +--------+-------+
# | Word   | Count |
# +--------+-------+
# | Lionel |   417 |
# | RT     |   323 |
# | Messi  |   287 |
# | -      |   206 |
# | gols   |   156 |
# | a      |   142 |
# | em     |   103 |
# | to     |    98 |
# | in     |    91 |
# | 🇦🇷     |    89 |
# +--------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | MessiLeoBrasil |    52 |
# | BarcaTimes     |    45 |
# | CuriosidadesEU |    25 |
# | YouTube        |    23 |
# | InvictosSomos  |    17 |
# | BarclaysLeague |    11 |
# | ChelseaFC      |    11 |
# | Bundesliga_EN  |    11 |
# | Squawka        |    10 |
# | BTLComps       |    10 |
# +----------------+-------+
# +-----------------+-------+
# | Hashtag         | Count |
# +-----------------+-------+
# | Messi           |    13 |
# | Goalphabet      |    11 |
# | futbol          |     9 |
# | deporte         |     9 |
# | cfc             |     3 |
# | SelfImprovement |     2 |
# | Motivation      |     2 |
# | epl             |     1 |
# | LionelMessi     |     1 |
# | CFC             |     1 |
# +-----------------+-------+

# %% [markdown]
# ## Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.1997531372145649
# 0.29683698296836986
# 0.391304347826087
# 19.600806451612904

# %% [markdown]
# ## Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-----------------+----------------------------------------------------+
# | Count | Screen Name     | Text                                               |
# +-------+-----------------+----------------------------------------------------+
# | 14861 | Sakkax10        | RT @Sakkax10: Ladies and gentlemen                 |
# |       |                 |                                                    |
# |       |                 | the greatest athlete of all time, Lionel Messi🐐.   |
# |       |                 | https://t.co/dbt4nhZIwM                            |
# | 14861 | Sakkax10        | RT @Sakkax10: Ladies and gentlemen                 |
# |       |                 |                                                    |
# |       |                 | the greatest athlete of all time, Lionel Messi🐐.   |
# |       |                 | https://t.co/dbt4nhZIwM                            |
# | 11901 | Shexxilona      | RT @Shexxilona: Whoever did this documentary of    |
# |       |                 | Lionel Messi deserves a statue.. It's really       |
# |       |                 | amazing 👏 https://t.co/wH5pFiENNF                  |
# | 11901 | Shexxilona      | RT @Shexxilona: Whoever did this documentary of    |
# |       |                 | Lionel Messi deserves a statue.. It's really       |
# |       |                 | amazing 👏 https://t.co/wH5pFiENNF                  |
# | 9343  | tenista_quemado | RT @tenista_quemado: 🇦🇷Lionel Messi: 31 años       |
# |       |                 | 🇪🇸Rafael Nadal: 32 años                            |
# |       |                 | 🇵🇹Cristiano Ronaldo: 33 años                       |
# |       |                 | 🇨🇭Roger Federer: 36 años                           |
# |       |                 |                                                    |
# |       |                 | En 10 años, qui…                                   |
# +-------+-----------------+----------------------------------------------------+

# %% [markdown]
# ## Example 11. Looking up users who have retweeted a status

# %%
# Get the original tweet id for a tweet from its retweeted_status node 
# and insert it here in place of the sample value that is provided
# from the text of the book

_retweets = twitter_api.statuses.retweets(id=317127304981667841)
print([r['user']['screen_name'] for r in _retweets])
# Out:
# ['melissacaaag', 'jyeee', 'Ceejaynatics', 'shekinahp_', 'LoveKyana18', 'kidamgos', 'asdfghjbl', 'josellexseraspi', 'anneyyeong']

# %% [markdown]
# ## Example 12. Plotting frequencies of words

# %%
import matplotlib.pyplot as plt

word_counts = sorted(Counter(words).values(), reverse=True)

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
# Out:
# Text(0.5,0,'Word Rank')

# %% [markdown]
# ## Example 13. Generating histograms of words, screen names, and hashtags

# %%
for label, data in (('Words', words), 
                    ('Screen Names', screen_names), 
                    ('Hashtags', hashtags)):

    # Build a frequency map for each set of data
    # and plot the values
    c = Counter(data)
    plt.hist(c.values())
    
    # Add a title and y-label ...
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    
    # ... and display as a new figure
    plt.figure()

# %% [markdown]
# ## Example 14. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
# Out:
# [6, 55, 28, 97, 3, 1, 45, 45, 9, 1, 84, 45, 22, 45, 3, 14861, 2, 45, 1098, 2, 9, 3, 37, 22, 45, 1, 301, 85, 5942, 85, 45, 1271, 97, 7, 505, 1, 28, 14861, 45, 97, 9, 37, 45, 45, 505, 240, 6, 47, 45, 6, 4, 85, 2, 7, 22, 47, 505, 1, 45, 55, 42, 7, 4, 45, 45, 4, 22, 6, 18, 45, 45, 45, 2, 505, 97, 19, 505, 3, 22, 7, 1, 19, 45, 47, 1271, 45, 505, 8, 7, 2, 1271, 45, 7, 45, 16, 55, 7, 22, 16, 45, 4, 55, 240, 200, 19, 45, 97, 19, 240, 55, 9343, 47, 55, 55, 55, 37, 45, 45, 7, 3, 55, 6, 505, 462, 1, 11901, 19, 19, 19, 45, 55, 4157, 55, 55, 19, 19, 45, 45, 45, 1709, 19, 22, 19, 19, 55, 2162, 45, 45, 45, 6, 505, 505, 4, 55, 45, 45, 534, 4, 45, 45, 55, 45, 45, 505, 45, 45, 55, 344, 45, 45, 85, 45, 121, 45, 37, 85, 85, 8, 55, 8, 4, 1, 126, 55, 283, 1271, 55, 126, 270, 97, 505, 11901, 1, 55, 283, 55, 22, 55, 505, 1098, 55, 7, 505, 462, 505, 55, 22, 465, 8, 55, 55, 8, 505, 283, 6, 8, 107, 485, 505, 55, 505, 505, 55, 22, 55, 8, 55, 1, 97, 8, 47, 55, 55, 283, 5, 8, 55, 55, 55, 48, 184, 37, 781, 505, 37, 55, 37, 4, 7, 55, 1043, 55, 1098, 55, 55, 7, 1, 184, 55, 55, 282, 184, 55, 55, 2029, 55, 184, 55, 184, 55, 184, 184, 184, 1, 55, 55, 55, 55, 47, 9, 6, 462, 85, 5942, 37, 3, 10, 504, 37, 1271, 4, 37, 1, 505, 189, 6, 97, 505, 505, 9, 7, 9, 5, 5942, 6, 1, 22, 85, 505, 20, 240, 37, 111, 7, 85, 505, 505, 4, 462, 85, 45, 7]

# %% [markdown]
# Note: This histogram gives you an idea of how many times tweets are retweeted with the x-axis defining partitions for tweets that have been retweeted some number of times and the y-axis telling you how many tweets fell into each bin. For example, a y-axis value of 5 for the "15-20 bin" on the x-axis means that there were 5 tweets that were retweeted between 15 and 20 times.
#
# Here's another variation that transforms the data using the (automatically imported from numpy) log function in order to improve the resolution of the plot.

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them
counts = [log(count) for count, _, _ in retweets]

# Taking the log of the *data values* themselves can 
# often provide quick and valuable insight into the
# underlying distribution as well. Try it back on
# Example 13 and see if it helps.

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Log[Bins (number of times retweeted)]')
plt.ylabel('Log[Number of tweets in bin]')

print(counts)
#log(counts)
# Out:
# [1.791759469228055, 4.007333185232471, 3.332204510175204, 4.574710978503383, 1.0986122886681098, 0.0, 3.8066624897703196, 3.8066624897703196, 2.1972245773362196, 0.0, 4.430816798843313, 3.8066624897703196, 3.091042453358316, 3.8066624897703196, 1.0986122886681098, 9.60649561075857, 0.6931471805599453, 3.8066624897703196, 7.001245622069476, 0.6931471805599453, 2.1972245773362196, 1.0986122886681098, 3.6109179126442243, 3.091042453358316, 3.8066624897703196, 0.0, 5.707110264748875, 4.442651256490317, 8.689801056022553, 4.442651256490317, 3.8066624897703196, 7.147559271189454, 4.574710978503383, 1.9459101490553132, 6.22455842927536, 0.0, 3.332204510175204, 9.60649561075857, 3.8066624897703196, 4.574710978503383, 2.1972245773362196, 3.6109179126442243, 3.8066624897703196, 3.8066624897703196, 6.22455842927536, 5.480638923341991, 1.791759469228055, 3.8501476017100584, 3.8066624897703196, 1.791759469228055, 1.3862943611198906, 4.442651256490317, 0.6931471805599453, 1.9459101490553132, 3.091042453358316, 3.8501476017100584, 6.22455842927536, 0.0, 3.8066624897703196, 4.007333185232471, 3.7376696182833684, 1.9459101490553132, 1.3862943611198906, 3.8066624897703196, 3.8066624897703196, 1.3862943611198906, 3.091042453358316, 1.791759469228055, 2.8903717578961645, 3.8066624897703196, 3.8066624897703196, 3.8066624897703196, 0.6931471805599453, 6.22455842927536, 4.574710978503383, 2.9444389791664403, 6.22455842927536, 1.0986122886681098, 3.091042453358316, 1.9459101490553132, 0.0, 2.9444389791664403, 3.8066624897703196, 3.8501476017100584, 7.147559271189454, 3.8066624897703196, 6.22455842927536, 2.0794415416798357, 1.9459101490553132, 0.6931471805599453, 7.147559271189454, 3.8066624897703196, 1.9459101490553132, 3.8066624897703196, 2.772588722239781, 4.007333185232471, 1.9459101490553132, 3.091042453358316, 2.772588722239781, 3.8066624897703196, 1.3862943611198906, 4.007333185232471, 5.480638923341991, 5.298317366548036, 2.9444389791664403, 3.8066624897703196, 4.574710978503383, 2.9444389791664403, 5.480638923341991, 4.007333185232471, 9.142382678792956, 3.8501476017100584, 4.007333185232471, 4.007333185232471, 4.007333185232471, 3.6109179126442243, 3.8066624897703196, 3.8066624897703196, 1.9459101490553132, 1.0986122886681098, 4.007333185232471, 1.791759469228055, 6.22455842927536, 6.135564891081739, 0.0, 9.38437770918244, 2.9444389791664403, 2.9444389791664403, 2.9444389791664403, 3.8066624897703196, 4.007333185232471, 8.332548939252638, 4.007333185232471, 4.007333185232471, 2.9444389791664403, 2.9444389791664403, 3.8066624897703196, 3.8066624897703196, 3.8066624897703196, 7.443663683115591, 2.9444389791664403, 3.091042453358316, 2.9444389791664403, 2.9444389791664403, 4.007333185232471, 7.6787889981991535, 3.8066624897703196, 3.8066624897703196, 3.8066624897703196, 1.791759469228055, 6.22455842927536, 6.22455842927536, 1.3862943611198906, 4.007333185232471, 3.8066624897703196, 3.8066624897703196, 6.280395838960195, 1.3862943611198906, 3.8066624897703196, 3.8066624897703196, 4.007333185232471, 3.8066624897703196, 3.8066624897703196, 6.22455842927536, 3.8066624897703196, 3.8066624897703196, 4.007333185232471, 5.840641657373398, 3.8066624897703196, 3.8066624897703196, 4.442651256490317, 3.8066624897703196, 4.795790545596741, 3.8066624897703196, 3.6109179126442243, 4.442651256490317, 4.442651256490317, 2.0794415416798357, 4.007333185232471, 2.0794415416798357, 1.3862943611198906, 0.0, 4.836281906951478, 4.007333185232471, 5.645446897643238, 7.147559271189454, 4.007333185232471, 4.836281906951478, 5.598421958998375, 4.574710978503383, 6.22455842927536, 9.38437770918244, 0.0, 4.007333185232471, 5.645446897643238, 4.007333185232471, 3.091042453358316, 4.007333185232471, 6.22455842927536, 7.001245622069476, 4.007333185232471, 1.9459101490553132, 6.22455842927536, 6.135564891081739, 6.22455842927536, 4.007333185232471, 3.091042453358316, 6.142037405587356, 2.0794415416798357, 4.007333185232471, 4.007333185232471, 2.0794415416798357, 6.224558429275 ...
